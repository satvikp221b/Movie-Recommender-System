# %%
from tmdbv3api import TMDb, Movie, Discover
import pandas as pd
import time

# Initialize TMDB API
tmdb = TMDb()
tmdb.api_key = '5d805336681cf24af0e0a0be49aa4f2f'

# TMDB objects
movie_api = Movie()
discover_api = Discover()

# Function to get movie details, including cast, crew, and keywords
def get_movie_details(movie_id):
    try:
        # Fetch movie details
        movie = movie_api.details(movie_id)
        
        # Fetch credits (cast and crew)
        credits = movie_api.credits(movie_id)
        
        # Fetch keywords
        keywords = movie_api.keywords(movie_id)
        
        # Extract relevant details
        movie_data = {
            'id': movie.id,
            'title': movie.title,
            'language': movie.original_language,
            'overview': movie.overview,
            'release_date': movie.release_date,
            'popularity': movie.popularity,
            'vote_average': movie.vote_average,
            'vote_count': movie.vote_count,
            'crew': credits['crew'] if 'crew' in credits else [],
            'cast': credits['cast'] if 'cast' in credits else [],
            'keywords': [kw['name'] for kw in keywords['keywords']] if 'keywords' in keywords else []
        }
        return movie_data
    except Exception as e:
        print(f"Error fetching movie {movie_id}: {e}")
        return None

# Function to get movies by language
def get_movies_by_language(language_code, total_movies):
    movies_data = []
    page = 1
    count = 0
    while count < total_movies:
        try:
            # Discover movies by language, paginated
            movies = discover_api.discover_movies({
                "with_original_language": language_code,
                "page": page,
                "sort_by": "popularity.desc"
            })
            
            # Fetch details for each movie
            for movie in movies:
                if count >= total_movies:
                    break
                movie_details = get_movie_details(movie.id)
                if movie_details:
                    movies_data.append(movie_details)
                    count += 1
                    #print(f"Fetched movie {count}/{total_movies} in {language_code}: {movie.title}")
            page += 1
            time.sleep(0.25)  # To avoid hitting rate limits
        except Exception as e:
            print(f"Error on page {page} for {language_code}: {e}")
            break
    return movies_data

# Fetch 10,000 English and 2,000 Hindi movies
english_movies = get_movies_by_language('en', 10000)
hindi_movies = get_movies_by_language('hi', 2000)

# Combine English and Hindi movies
all_movies = english_movies + hindi_movies

# Convert to a DataFrame
combined_df = pd.DataFrame(all_movies)

# Save the combined dataset to CSV
combined_df.to_csv('movies_df.csv', index=False)

print("Combined movie dataset saved successfully.")
# Out:
# Error fetching movie 957: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Max retries exceeded with url: /3/movie/957?api_key=5d805336681cf24af0e0a0be49aa4f2f&append_to_response=videos,trailers,images,casts,translations,keywords,release_dates&language=en-US (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022A642CB4F0>: Failed to establish a new connection: [WinError 10055] An operation on a socket could not be performed because the system lacked sufficient buffer space or because a queue was full'))
# Error fetching movie 1187107: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Max retries exceeded with url: /3/movie/1187107?api_key=5d805336681cf24af0e0a0be49aa4f2f&append_to_response=videos,trailers,images,casts,translations,keywords,release_dates&language=en-US (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022A64327CD0>: Failed to establish a new connection: [WinError 10055] An operation on a socket could not be performed because the system lacked sufficient buffer space or because a queue was full'))
# Error fetching movie 523781: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Max retries exceeded with url: /3/movie/523781?api_key=5d805336681cf24af0e0a0be49aa4f2f&append_to_response=videos,trailers,images,casts,translations,keywords,release_dates&language=en-US (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022A6433AD60>: Failed to establish a new connection: [WinError 10055] An operation on a socket could not be performed because the system lacked sufficient buffer space or because a queue was full'))
# Error fetching movie 59231: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Max retries exceeded with url: /3/movie/59231?api_key=5d805336681cf24af0e0a0be49aa4f2f&append_to_response=videos,trailers,images,casts,translations,keywords,release_dates&language=en-US (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022A6432A5B0>: Failed to establish a new connection: [WinError 10055] An operation on a socket could not be performed because the system lacked sufficient buffer space or because a queue was full'))
# Error fetching movie 1067485: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Max retries exceeded with url: /3/movie/1067485?api_key=5d805336681cf24af0e0a0be49aa4f2f&append_to_response=videos,trailers,images,casts,translations,keywords,release_dates&language=en-US (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022A6432AE50>: Failed to establish a new connection: [WinError 10055] An operation on a socket could not be performed because the system lacked sufficient buffer space or because a queue was full'))
# Error fetching movie 76285: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Max retries exceeded with url: /3/movie/76285?api_key=5d805336681cf24af0e0a0be49aa4f2f&append_to_response=videos,trailers,images,casts,translations,keywords,release_dates&language=en-US (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022A642F2760>: Failed to establish a new connection: [WinError 10055] An operation on a socket could not be performed because the system lacked sufficient buffer space or because a queue was full'))
# Error fetching movie 47327: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Max retries exceeded with url: /3/movie/47327?api_key=5d805336681cf24af0e0a0be49aa4f2f&append_to_response=videos,trailers,images,casts,translations,keywords,release_dates&language=en-US (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022A642F7070>: Failed to establish a new connection: [WinError 10055] An operation on a socket could not be performed because the system lacked sufficient buffer space or because a queue was full'))
# Error fetching movie 8337: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Max retries exceeded with url: /3/movie/8337?api_key=5d805336681cf24af0e0a0be49aa4f2f&append_to_response=videos,trailers,images,casts,translations,keywords,release_dates&language=en-US (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022A6432AEE0>: Failed to establish a new connection: [WinError 10055] An operation on a socket could not be performed because the system lacked sufficient buffer space or because a queue was full'))
# Error fetching movie 27352: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Max retries exceeded with url: /3/movie/27352?api_key=5d805336681cf24af0e0a0be49aa4f2f&append_to_response=videos,trailers,images,casts,translations,keywords,release_dates&language=en-US (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022A6432A730>: Failed to establish a new connection: [WinError 10055] An operation on a socket could not be performed because the system lacked sufficient buffer space or because a queue was full'))
# Error fetching movie 635237: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Max retries exceeded with url: /3/movie/635237?api_key=5d805336681cf24af0e0a0be49aa4f2f&append_to_response=videos,trailers,images,casts,translations,keywords,release_dates&language=en-US (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022A6406A040>: Failed to establish a new connection: [WinError 10055] An operation on a socket could not be performed because the system lacked sufficient buffer space or because a queue was full'))
# Error fetching movie 10425: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Max retries exceeded with url: /3/movie/10425?api_key=5d805336681cf24af0e0a0be49aa4f2f&append_to_response=videos,trailers,images,casts,translations,keywords,release_dates&language=en-US (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022A642CB130>: Failed to establish a new connection: [WinError 10055] An operation on a socket could not be performed because the system lacked sufficient buffer space or because a queue was full'))
# Error fetching movie 556901: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Max retries exceeded with url: /3/movie/556901?api_key=5d805336681cf24af0e0a0be49aa4f2f&append_to_response=videos,trailers,images,casts,translations,keywords,release_dates&language=en-US (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022A64327CA0>: Failed to establish a new connection: [WinError 10055] An operation on a socket could not be performed because the system lacked sufficient buffer space or because a queue was full'))
# Error fetching movie 1143128: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Max retries exceeded with url: /3/movie/1143128?api_key=5d805336681cf24af0e0a0be49aa4f2f&append_to_response=videos,trailers,images,casts,translations,keywords,release_dates&language=en-US (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022A642F7940>: Failed to establish a new connection: [WinError 10055] An operation on a socket could not be performed because the system lacked sufficient buffer space or because a queue was full'))
# Error fetching movie 1035803: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Max retries exceeded with url: /3/movie/1035803?api_key=5d805336681cf24af0e0a0be49aa4f2f&append_to_response=videos,trailers,images,casts,translations,keywords,release_dates&language=en-US (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022A64262640>: Failed to establish a new connection: [WinError 10055] An operation on a socket could not be performed because the system lacked sufficient buffer space or because a queue was full'))
# Error fetching movie 20764: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Max retries exceeded with url: /3/movie/20764?api_key=5d805336681cf24af0e0a0be49aa4f2f&append_to_response=videos,trailers,images,casts,translations,keywords,release_dates&language=en-US (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022A6424ACA0>: Failed to establish a new connection: [WinError 10055] An operation on a socket could not be performed because the system lacked sufficient buffer space or because a queue was full'))
# Error fetching movie 11856: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Max retries exceeded with url: /3/movie/11856?api_key=5d805336681cf24af0e0a0be49aa4f2f&append_to_response=videos,trailers,images,casts,translations,keywords,release_dates&language=en-US (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022A6432A3A0>: Failed to establish a new connection: [WinError 10055] An operation on a socket could not be performed because the system lacked sufficient buffer space or because a queue was full'))
# Error fetching movie 11472: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Max retries exceeded with url: /3/movie/11472?api_key=5d805336681cf24af0e0a0be49aa4f2f&append_to_response=videos,trailers,images,casts,translations,keywords,release_dates&language=en-US (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022A6432A640>: Failed to establish a new connection: [WinError 10055] An operation on a socket could not be performed because the system lacked sufficient buffer space or because a queue was full'))
# Error on page 269 for en: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Max retries exceeded with url: /3/discover/movie?api_key=5d805336681cf24af0e0a0be49aa4f2f&with_original_language=en&page=269&sort_by=popularity.desc&language=en-US (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022A642F2400>: Failed to establish a new connection: [WinError 10055] An operation on a socket could not be performed because the system lacked sufficient buffer space or because a queue was full'))
# Error on page 1 for hi: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Max retries exceeded with url: /3/discover/movie?api_key=5d805336681cf24af0e0a0be49aa4f2f&with_original_language=hi&page=1&sort_by=popularity.desc&language=en-US (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022A642FB220>: Failed to establish a new connection: [WinError 10055] An operation on a socket could not be performed because the system lacked sufficient buffer space or because a queue was full'))
# Combined movie dataset saved successfully.

# %%
len(combined_df)
# Out:
# 5343

# %%
combined_df
# Out:
#            id                                      title language  \
# 0      533535                       Deadpool & Wolverine       en
# 1      519182                            Despicable Me 4       en
# 2     1114513                              Speak No Evil       en
# 3      877817                                      Wolfs       en
# 4      957452                                   The Crow       en
# ...       ...                                        ...      ...
# 5338     3602  I'll Always Know What You Did Last Summer       en
# 5339    38321                                     Priest       en
# 5340    10371                       For Richer or Poorer       en
# 5341    17058                             Scarlet Street       en
# 5342  1134562                  The Woman Under the Stage       en
#
#                                                overview release_date  \
# 0     A listless Wade Wilson toils away in civilian ...   2024-07-24
# 1     Gru and Lucy and their girls—Margo, Edith and ...   2024-06-20
# 2     When an American family is invited to spend th...   2024-09-11
# 3     Hired to cover up a high-profile crime, a fixe...   2024-09-20
# 4     Soulmates Eric and Shelly are brutally murdere...   2024-08-21
# ...                                                 ...          ...
# 5338  Several teenagers in a small-town in Colorado ...   2006-06-24
# 5339  In an alternate world, humanity and vampires h...   2011-05-05
# 5340  Brad Sexton and his wife, Caroline, are wealth...   1997-12-11
# 5341  Cashier and part-time starving artist Christop...   1945-12-25
# 5342  A young woman discovers just how far she will ...   2023-08-03
#
#       popularity  vote_average  vote_count  \
# 0       5099.804         7.700        4056
# 1       2524.611         7.142        1895
# 2       2281.291         7.343         524
# 3       1693.793         6.594         383
# 4       1690.146         5.441         486
# ...          ...           ...         ...
# 5338      19.865         4.201         376
# 5339      19.860         5.797        2228
# 5340      19.860         5.942         224
# 5341      19.859         7.600         374
# 5342      19.858         0.000           0
#
#                                                    crew  \
# 0     [[adult, gender, id, known_for_department, nam...
# 1     [[adult, gender, id, known_for_department, nam...
# 2     [[adult, gender, id, known_for_department, nam...
# 3     [[adult, gender, id, known_for_department, nam...
# 4     [[adult, gender, id, known_for_department, nam...
# ...                                                 ...
# 5338  [[adult, gender, id, known_for_department, nam...
# 5339  [[adult, gender, id, known_for_department, nam...
# 5340  [[adult, gender, id, known_for_department, nam...
# 5341  [[adult, gender, id, known_for_department, nam...
# 5342  [[adult, gender, id, known_for_department, nam...
#
#                                                    cast keywords
# 0     [[adult, gender, id, known_for_department, nam...       []
# 1     [[adult, gender, id, known_for_department, nam...       []
# 2     [[adult, gender, id, known_for_department, nam...       []
# 3     [[adult, gender, id, known_for_department, nam...       []
# 4     [[adult, gender, id, known_for_department, nam...       []
# ...                                                 ...      ...
# 5338  [[adult, gender, id, known_for_department, nam...       []
# 5339  [[adult, gender, id, known_for_department, nam...       []
# 5340  [[adult, gender, id, known_for_department, nam...       []
# 5341  [[adult, gender, id, known_for_department, nam...       []
# 5342  [[adult, gender, id, known_for_department, nam...       []
#
# [5343 rows x 11 columns]

# %%
combined_df['crew'][0]
# Out:
# [{'adult': False, 'gender': 2, 'id': 17825, 'known_for_department': 'Directing', 'name': 'Shawn Levy', 'original_name': 'Shawn Levy', 'popularity': 23.335, 'profile_path': '/j1CXZgmfvFeD7S3PYtsEk8H3ebB.jpg', 'credit_id': '622bc4c8a579f9006f1f0a6d', 'department': 'Directing', 'job': 'Director'}, {'adult': False, 'gender': 2, 'id': 7932, 'known_for_department': 'Writing', 'name': 'Rhett Reese', 'original_name': 'Rhett Reese', 'popularity': 6.077, 'profile_path': '/8QjgT3ffjzSTfih5C0LpFEea5Ps.jpg', 'credit_id': '622be2de9a358d0071934f94', 'department': 'Writing', 'job': 'Writer'}, {'adult': False, 'gender': 2, 'id': 91269, 'known_for_department': 'Writing', 'name': 'Paul Wernick', 'original_name': 'Paul Wernick', 'popularity': 8.0, 'profile_path': '/12wCVgUkLv7RejadXXZrtL8Tj5N.jpg', 'credit_id': '622be2ea24f2ce001d7e0365', 'department': 'Writing', 'job': 'Writer'}, {'adult': False, 'gender': 2, 'id': 24192, 'known_for_department': 'Sound', 'name': 'Dave Jordan', 'original_name': 'Dave Jordan', 'popularity': 3.629, 'profile_path': '/btzUgkKCllxClxIgLhmhZ1qaPw.jpg', 'credit_id': '65493a401ac2927b3028ca48', 'department': 'Sound', 'job': 'Music Supervisor'}, {'adult': False, 'gender': 1, 'id': 1266574, 'known_for_department': 'Art', 'name': 'Naomi Moore', 'original_name': 'Naomi Moore', 'popularity': 0.402, 'profile_path': None, 'credit_id': '654939e72866fa00e1f021d9', 'department': 'Art', 'job': 'Set Decoration'}, {'adult': False, 'gender': 2, 'id': 1842127, 'known_for_department': 'Editing', 'name': 'Shane Reid', 'original_name': 'Shane Reid', 'popularity': 3.139, 'profile_path': '/idptgX7GBTwqcM7WKKaChThDFQN.jpg', 'credit_id': '656244223679a1097873b704', 'department': 'Editing', 'job': 'Editor'}, {'adult': False, 'gender': 2, 'id': 57027, 'known_for_department': 'Production', 'name': "Louis D'Esposito", 'original_name': "Louis D'Esposito", 'popularity': 5.931, 'profile_path': '/mPy6hxHrHoEOWdljLyZM6DNBSPn.jpg', 'credit_id': '6333c20dd465370082a9ee7b', 'department': 'Production', 'job': 'Executive Producer'}, {'adult': False, 'gender': 2, 'id': 10859, 'known_for_department': 'Acting', 'name': 'Ryan Reynolds', 'original_name': 'Ryan Reynolds', 'popularity': 182.265, 'profile_path': '/algQ1VEno2W9SesoArWcZTeF617.jpg', 'credit_id': '6333da1330f79c008f664626', 'department': 'Production', 'job': 'Producer'}, {'adult': False, 'gender': 2, 'id': 10859, 'known_for_department': 'Acting', 'name': 'Ryan Reynolds', 'original_name': 'Ryan Reynolds', 'popularity': 182.265, 'profile_path': '/algQ1VEno2W9SesoArWcZTeF617.jpg', 'credit_id': '6333da45eec4f300801b6800', 'department': 'Writing', 'job': 'Writer'}, {'adult': False, 'gender': 2, 'id': 7932, 'known_for_department': 'Writing', 'name': 'Rhett Reese', 'original_name': 'Rhett Reese', 'popularity': 6.077, 'profile_path': '/8QjgT3ffjzSTfih5C0LpFEea5Ps.jpg', 'credit_id': '65c9602e266778017c598c50', 'department': 'Production', 'job': 'Executive Producer'}, {'adult': False, 'gender': 1, 'id': 7200, 'known_for_department': 'Production', 'name': 'Lauren Shuler Donner', 'original_name': 'Lauren Shuler Donner', 'popularity': 3.681, 'profile_path': '/a0oY5BiS6ubJv3Mxh83XH8S4fH7.jpg', 'credit_id': '65c95fe3ce6c4c017cbaee00', 'department': 'Production', 'job': 'Producer'}, {'adult': False, 'gender': 1, 'id': 57634, 'known_for_department': 'Production', 'name': 'Mary McLaglen', 'original_name': 'Mary McLaglen', 'popularity': 4.914, 'profile_path': '/p2Ll42Ov1ZusGSKGJeyy5MCeP7R.jpg', 'credit_id': '65c96020aaec71019b59e2bc', 'department': 'Production', 'job': 'Executive Producer'}, {'adult': False, 'gender': 2, 'id': 10956, 'known_for_department': 'Directing', 'name': 'Josh McLaglen', 'original_name': 'Josh McLaglen', 'popularity': 5.709, 'profile_path': '/5PJWCWlKF3kJWOHSqs7l7M7nZK9.jpg', 'credit_id': '65c96028ce6c4c0149b9796b', 'department': 'Production', 'job': 'Executive Producer'}, {'adult': False, 'gender': 2, 'id': 11092, 'known_for_department': 'Production', 'name': 'Simon Kinberg', 'original_name':  ...
