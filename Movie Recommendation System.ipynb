# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ast
from scipy import stats
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import wordnet
from surprise import Reader, Dataset, SVD

import warnings; warnings.simplefilter('ignore')

# %% [markdown]
# ## Loading the dataset

# %%
movies_df=pd.read_csv('movies_metadata.csv')
credits_df=pd.read_csv('credits.csv')
ratings_df=pd.read_csv('ratings_small.csv')
keywords_df=pd.read_csv('keywords.csv')
links_df=pd.read_csv('links_small.csv')

# %%
movies_df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Cleaning Data

# %%
# Convert 'release_date' to datetime and extract the year
movies_df['release_date'] = pd.to_datetime(movies_df['release_date'], errors='coerce')
movies_df['year'] = movies_df['release_date'].dt.year

# %%
# Drop rows with missing 'year'
movies_df = movies_df.dropna(subset=['year'])

# %%
movies_df['year']=movies_df['year'].astype(int)

# %%
# Ensure the necessary columns are of the correct type
movies_df['vote_count'] = movies_df['vote_count'].astype(int)
movies_df['vote_average'] = movies_df['vote_average'].astype(float)
movies_df['popularity'] = movies_df['popularity'].astype(float)

# %% [markdown]
# ## Bayesian Recommender System
#
# The **Bayesian Recommender System** is an alternative to IMDB’s weighted rating system, providing a more robust ranking mechanism by factoring in the number of votes each movie receives. This system helps balance out movies with few votes and ensures that movies with a significant number of votes and a high average rating appear in the top recommendations.
#
# ### Bayesian Average Formula:
#
# The formula for Bayesian Average (BA) is:
#
# $ \text{Bayesian Average (BA)} = \frac{Rv + Cm}{v + m} $
#
# Where:
# - `R`: Average rating of the movie
# - `v`: Number of votes for the movie
# - `C`: Mean rating across all movies
# - `m`: Minimum number of votes required to qualify (calculated dynamically)
#
# In this system, `m` is calculated dynamically as the **95th percentile** of vote counts across all movies for the overall chart and as the **85th percentile** for genre-specific charts.

# %%
# Calculate the mean vote across all movies
C = movies_df['vote_average'].mean()

# %%
# Calculate the 95th percentile for vote_count
m = movies_df['vote_count'].quantile(0.95)

# %%
def bayesian_average(x, m=m, C=C):
    """Calculates bayesian average for each movie"""
    v = x['vote_count']
    R = x['vote_average']
    return (R * v + C * m) / (v + m)

# %%
# Filter movies that qualify for the top chart
qualified_movies = movies_df[movies_df['vote_count'] >= m].copy()

# %%
# Calculate the Bayesian average rating for each qualified movie
qualified_movies['bayesian_rating'] = qualified_movies.apply(bayesian_average, axis=1)

# %%
def top_n_movies(df,n):
    """Get the top 'n' movies that are based off the bayesian ratings"""
    return df.sort_values('bayesian_rating', ascending=False)[['title', 'year', 'vote_count', 'vote_average', 'popularity']].head(n)

# %%
top_15=top_n_movies(qualified_movies,15)

# %% [markdown]
# ### Top 15 Movies According to Bayesian Ratings

# %%
top_15
# Out:
#                           title  year  vote_count  vote_average  popularity
# 314    The Shawshank Redemption  1994        8358           8.5   51.645403
# 834               The Godfather  1972        6024           8.5   41.109264
# 12481           The Dark Knight  2008       12269           8.3  123.167259
# 2843                 Fight Club  1999        9678           8.3   63.869599
# 292                Pulp Fiction  1994        8670           8.3  140.950236
# 351                Forrest Gump  1994        8147           8.2   48.307194
# 522            Schindler's List  1993        4436           8.3   41.725123
# 23673                  Whiplash  2014        4376           8.3   64.299990
# 5481              Spirited Away  2001        3968           8.3   41.048867
# 1154    The Empire Strikes Back  1980        5998           8.2   19.470959
# 15480                 Inception  2010       14075           8.1   29.108149
# 2211          Life Is Beautiful  1997        3643           8.3   39.394970
# 18465          The Intouchables  2011        5410           8.2   16.086919
# 22879              Interstellar  2014       11187           8.1   32.213481
# 1178     The Godfather: Part II  1974        3418           8.3   36.629307

# %% [markdown]
# This matches up with common logic because shawshank is at the top. Understandable.

# %%
def convert_genres(genres):
    """Clean genres column from JSON like format to String"""
    try:
        genre_list = ast.literal_eval(genres)  # Safely evaluate string as a list
        genre_names = [genre['name'] for genre in genre_list]  # Extract genre names
        return ', '.join(genre_names)  # Join genre names into a single string
    except (ValueError, SyntaxError):
        return np.nan  # Return NaN if there's an issue with the format

# %%
# Clean 'genres' column
movies_df['genre'] = movies_df['genres'].apply(convert_genres)

# Drop rows where genre conversion failed
movies_df = movies_df.dropna(subset=['genre'])

# %%
movies_df[['title','genre']].head()
# Out:
#                          title                       genre
# 0                    Toy Story   Animation, Comedy, Family
# 1                      Jumanji  Adventure, Fantasy, Family
# 2             Grumpier Old Men             Romance, Comedy
# 3            Waiting to Exhale      Comedy, Drama, Romance
# 4  Father of the Bride Part II                      Comedy

# %%
def genre_chart_bayesian(genre, percentile=0.85, n= 15):
    """Build Charts for a particular genre using Bayesian rating"""
    genre_movies = movies_df[movies_df['genre'].str.contains(genre, na=False)].copy()
    genre_m = genre_movies['vote_count'].quantile(percentile)
    qualified_genre_movies = genre_movies[genre_movies['vote_count'] >= genre_m]
    qualified_genre_movies['bayesian_rating'] = qualified_genre_movies.apply(bayesian_average, axis=1)
    
    # Sort by Bayesian rating and return top movies in this genre
    return qualified_genre_movies.sort_values('bayesian_rating', ascending=False)[['title', 'year', 'vote_count', 'vote_average', 'popularity']].head(n)

# %%
## Get the top 15 Action Movies according to Bayesian Rating Average
top_action_movies = genre_chart_bayesian('Action', percentile=0.85,n=15)
top_action_movies
# Out:
#                                                    title  year  vote_count  \
# 12481                                    The Dark Knight  2008       12269
# 1154                             The Empire Strikes Back  1980        5998
# 15480                                          Inception  2010       14075
# 7000       The Lord of the Rings: The Return of the King  2003        8226
# 256                                            Star Wars  1977        6778
# 4863   The Lord of the Rings: The Fellowship of the Ring  2001        8892
# 5814               The Lord of the Rings: The Two Towers  2002        7641
# 23753                            Guardians of the Galaxy  2014       10014
# 2458                                          The Matrix  1999        9079
# 13605                               Inglourious Basterds  2009        6598
# 3456                                           Gladiator  2000        5566
# 1167                                  Return of the Jedi  1983        4763
# 1171                                               Alien  1979        4564
# 4135                                            Scarface  1983        3017
# 24455                                         Big Hero 6  2014        6289
#
#        vote_average  popularity
# 12481           8.3  123.167259
# 1154            8.2   19.470959
# 15480           8.1   29.108149
# 7000            8.1   29.324358
# 256             8.1   42.149697
# 4863            8.0   32.070725
# 5814            8.0   29.423537
# 23753           7.9   53.291601
# 2458            7.9   33.366332
# 13605           7.9   16.895640
# 3456            7.9   23.186667
# 1167            7.9   14.586087
# 1171            7.9   23.377420
# 4135            8.0   11.299673
# 24455           7.8  213.849907

# %% [markdown]
# The Dark Knight. No surprises here!

# %% [markdown]
# ## Content-Based Recommender

# %% [markdown]
# ### Overview and Tagline into consideration

# %%
links_df = links_df[links_df['tmdbId'].notnull()]['tmdbId'].astype('int')

# %%
len(links_df)
# Out:
# 9112

# %%
movies_df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45460  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45460  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45460                                   NaN   30840  tt0102797
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# 45465                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45460                en                   Robin Hood
# 45462                tl          Siglo ng Pagluluwal
# 45463                en                     Betrayal
# 45464                en          Satana likuyushchiy
# 45465                en                     Queerama
#
#                                                 overview  ...  runtime  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...     81.0
# 1      When siblings Judy and Peter discover an encha...  ...    104.0
# 2      A family wedding reignites the ancient feud be...  ...    101.0
# 3      Cheated on, mistreated and stepped on, the wom...  ...    127.0
# 4      Just when George Banks has recovered from his ...  ...    106.0
# ...                                                  ...  ...      ...
# 45460  Yet another version of the classic epic, with ...  ...    104.0
# 45462  An artist struggles to finish his work while a...  ...    360.0
# 45463  When one of her hits goes wrong, a professiona...  ...     90.0
# 45464  In a small town live two brothers, one a minis...  ...     87.0
# 45465  50 years after decriminalisation of homosexual...  ...     75.0
#
#                                         spoken_languages    status  \
# 0               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                  ...       ...
# 45460           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45462                  [{'iso_639_1': 'tl', 'name': ''}]  Released
# 45463           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45464                                                 []  Released
# 45465           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45460                                                NaN
# 45462                                                NaN
# 45463                             A deadly game of wits.
# 45464                                                NaN
# 45465                                                NaN
#
#                              title  video  vote_average vote_count  year  \
# 0                        Toy Story  False           7.7       5415  1995
# 1                          Jumanji  False           6.9       2413  1995
# 2                 Grumpier Old Men  False           6.5         92  1995
# 3                Waiting to Exhale  False           6.1         34  1995
# 4      Father of the Bride Part II  False           5.7        173  1995
# ...                            ...    ...           ...        ...   ...
# 45460                   Robin Hood  False           5.7         26  1991
# 45462          Century of Birthing  False           9.0          3  2011
# 45463                     Betrayal  False           3.8          6  2003
# 45464             Satan Triumphant  False           0.0          0  1917
# 45465                     Queerama  False           0.0          0  2017
#
#                             genre
# 0       Animation, Comedy, Family
# 1      Adventure, Fantasy, Family
# 2                 Romance, Comedy
# 3          Comedy, Drama, Romance
# 4                          Comedy
# ...                           ...
# 45460      Drama, Action, Romance
# 45462                       Drama
# 45463     Action, Drama, Thriller
# 45464
# 45465
#
# [45376 rows x 26 columns]

# %%
movies_df['id']=movies_df['id'].astype(int)

# %%
small_movies_df=movies_df[movies_df['id'].isin(links_df)]

# %%
small_movies_df.shape
# Out:
# (9099, 26)

# %%
# Fill missing values in overview and tagline with empty strings
small_movies_df['overview'] = small_movies_df['overview'].fillna('')
small_movies_df['tagline'] = small_movies_df['tagline'].fillna('')

# %%
# Combine overview and tagline into one column
small_movies_df['overview_tagline'] = small_movies_df['overview'] + ' ' + small_movies_df['tagline']

# %%
# Create a TF-IDF Vectorizer to transform text into vectors
tfidf = TfidfVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0,stop_words='english')

# %%
# Fit and transform the combined overview and tagline column
tfidf_matrix = tfidf.fit_transform(small_movies_df['overview_tagline'])

# %%
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
small_movies_df = small_movies_df.reset_index()
titles = small_movies_df['title']
#indices = pd.Series(small_movies_df.index, index=small_movies_df['title'])

# %%
# Function to get movie recommendations based on overview and tagline similarity
def get_recommendations(title, cosine_sim=cosine_sim):
    # Get the index of the movie that matches the title
    idx = small_movies_df[small_movies_df['title'] == title].index[0]
    
    # Get the pairwise similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))
    
    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:11]  # Exclude the first movie as it will be itself
    
    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]
    
    # Return the top 10 most similar movies
    return small_movies_df[['title', 'overview', 'tagline']].iloc[movie_indices]

# %%
get_recommendations('Sherlock, Jr.')
# Out:
#                                            title  \
# 284                     The Shawshank Redemption
# 8125  The Making of a Legend: Gone with the Wind
# 2210                     The Thomas Crown Affair
# 2519                               Stealing Home
# 589                                   True Crime
# 1093                    The Mirror Has Two Faces
# 927                              Cinema Paradiso
# 5808                                Police Story
# 5656                         Steamboat Bill, Jr.
# 8482                             I, Frankenstein
#
#                                                overview  \
# 284   Framed in the 1940s for the double murder of h...
# 8125  This is a documentary that revisits the making...
# 2210  A very rich and successful playboy amuses hims...
# 2519  Billy Wyatt (Harmon), a former high school and...
# 589   Mary Giordano is a bright, intelligent student...
# 1093  Rose Morgan (Barbara Streisand), who still liv...
# 927   A filmmaker recalls his childhood, when he fel...
# 5808  A virtuous Hong Kong police officer must clear...
# 5656  The just out of college effete son of a no-non...
# 8482  200 years after his shocking creation, Dr. Fra...
#
#                                                 tagline
# 284   Fear can hold you prisoner. Hope can set you f...
# 8125
# 2210         How do you get the man who has everything?
# 2519  Stealing hearts, stealing laughs, stealing mem...
# 589                                       Trust no one.
# 1093  A story about just how wrong two people can be...
# 927   A celebration of youth, friendship, and the ev...
# 5808   You may know the name, but the game has changed.
# 5656              The Laugh Special of the Age. See It.
# 8482  In the battle between good and evil, an immort...

# %% [markdown]
# ### Taking Cast and Crew into consideration as well

# %%
credits_df.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %%
keywords_df.head()
# Out:
#       id                                           keywords
# 0    862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1   8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...

# %%
keywords_df['id'] = keywords_df['id'].astype('int')
credits_df['id'] = credits_df['id'].astype('int')
movies_df['id'] = movies_df['id'].astype('int')

# %% [markdown]
# Making the final df with merged crew and keyword information

# %%
movies_df=movies_df.merge(keywords_df,on='id')

# %%
movies_df=movies_df.merge(credits_df,on='id')

# %%
small_movies_df=movies_df[movies_df['id'].isin(links_df)]

# %%
small_movies_df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ...  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...
# 1  When siblings Judy and Peter discover an encha...  ...
# 2  A family wedding reignites the ancient feud be...  ...
# 3  Cheated on, mistreated and stepped on, the wom...  ...
# 4  Just when George Banks has recovered from his ...  ...
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count  year  \
# 0                    Toy Story  False          7.7       5415  1995
# 1                      Jumanji  False          6.9       2413  1995
# 2             Grumpier Old Men  False          6.5         92  1995
# 3            Waiting to Exhale  False          6.1         34  1995
# 4  Father of the Bride Part II  False          5.7        173  1995
#
#                         genre  \
# 0   Animation, Comedy, Family
# 1  Adventure, Fantasy, Family
# 2             Romance, Comedy
# 3      Comedy, Drama, Romance
# 4                      Comedy
#
#                                             keywords  \
# 0  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
#
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...
#
# [5 rows x 29 columns]

# %%
small_movies_df['cast'] = small_movies_df['cast'].apply(ast.literal_eval)
small_movies_df['crew'] = small_movies_df['crew'].apply(ast.literal_eval)
small_movies_df['keywords'] = small_movies_df['keywords'].apply(ast.literal_eval)
small_movies_df['cast_size'] = small_movies_df['cast'].apply(lambda x: len(x))
small_movies_df['crew_size'] = small_movies_df['crew'].apply(lambda x: len(x))

# %%
small_movies_df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ...  video vote_average  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...  False          7.7
# 1  When siblings Judy and Peter discover an encha...  ...  False          6.9
# 2  A family wedding reignites the ancient feud be...  ...  False          6.5
# 3  Cheated on, mistreated and stepped on, the wom...  ...  False          6.1
# 4  Just when George Banks has recovered from his ...  ...  False          5.7
#
#   vote_count  year                       genre  \
# 0       5415  1995   Animation, Comedy, Family
# 1       2413  1995  Adventure, Fantasy, Family
# 2         92  1995             Romance, Comedy
# 3         34  1995      Comedy, Drama, Romance
# 4        173  1995                      Comedy
#
#                                             keywords  \
# 0  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
#
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': 'Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew cast_size crew_size
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...        13       106
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...        26        16
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...         7         4
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...        10        10
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...        12         7
#
# [5 rows x 31 columns]

# %%
def get_director(x):
    """Get Director Info from crew column"""
    for i in x:
        if i['job'] == 'Director':
            return i['name']
    return ''

# %%
small_movies_df['director']=small_movies_df['crew'].apply(get_director)

# %%
def get_cast(x):
    """Get the top 3 starring cast 
    cast=[]
    for i in x:
        cast.append(i['name'])
    if len(cast)>=3:
        cast=cast[:3]
    return cast

# %%
small_movies_df['cast_names'] = small_movies_df['cast'].apply(get_cast)

# %%
def get_keywords(x):
    keywords=[]
    for i in x:
        keywords.append(i['name'])
    return keywords

# %%
small_movies_df['keywords_info']=small_movies_df['keywords'].apply(get_keywords)

# %%
# Function to convert list of dictionaries to string of names (for cast, keywords)
def convert_list_to_string(data_list):
    """Convert List of Objects to String"""
    return ' ,'.join([item for item in data_list]) if isinstance(data_list, list) else ''

# %%
# Apply the function to convert lists in 'cast', 'keywords', 'crew'
small_movies_df['cast_names'] = small_movies_df['cast_names'].apply(lambda x: convert_list_to_string(x))  
small_movies_df['keywords_info'] = small_movies_df['keywords_info'].apply(lambda x: convert_list_to_string(x))

# %%
small_movies_df.reset_index(inplace=True)

# %%
small_movies_df
# Out:
#       index  adult                              belongs_to_collection  \
# 0         0  False  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1         1  False                                                NaN
# 2         2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3         3  False                                                NaN
# 4         4  False  {'id': 96871, 'name': 'Father of the Bride Col...
# ...     ...    ...                                                ...
# 9214  40894  False                                                NaN
# 9215  41114  False                                                NaN
# 9216  41167  False                                                NaN
# 9217  41330  False                                                NaN
# 9218  41608  False                                                NaN
#
#         budget                                             genres  \
# 0     30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1     65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2            0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3     16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4            0                     [{'id': 35, 'name': 'Comedy'}]
# ...        ...                                                ...
# 9214   8000000                      [{'id': 18, 'name': 'Drama'}]
# 9215   1000000  [{'id': 53, 'name': 'Thriller'}, {'id': 10749,...
# 9216  15050000  [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...
# 9217  15000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 9218         0  [{'id': 99, 'name': 'Documentary'}, {'id': 104...
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 9214                                    NaN  159550  tt0255313
# 9215                                    NaN  392572  tt5165344
# 9216                                    NaN  402672  tt3859980
# 9217                                    NaN  315011  tt4262980
# 9218  http://www.thebeatlesliveproject.com/  391698  tt2531318
#
#      original_language                                     original_title  \
# 0                   en                                          Toy Story
# 1                   en                                            Jumanji
# 2                   en                                   Grumpier Old Men
# 3                   en                                  Waiting to Exhale
# 4                   en                        Father of the Bride Part II
# ...                ...                                                ...
# 9214                en                     The Last Brickmaker in America
# 9215                hi                                             रुस्तम
# 9216                hi                                       Mohenjo Daro
# 9217                ja                                             シン・ゴジラ
# 9218                en  The Beatles: Eight Days a Week - The Touring Y...
#
#       ...  year                                              genre  \
# 0     ...  1995                          Animation, Comedy, Family
# 1     ...  1995                         Adventure, Fantasy, Family
# 2     ...  1995                                    Romance, Comedy
# 3     ...  1995                             Comedy, Drama, Romance
# 4     ...  1995                                             Comedy
# ...   ...   ...                                                ...
# 9214  ...  2001                                              Drama
# 9215  ...  2016                                  Thriller, Romance
# 9216  ...  2016                 Adventure, Drama, History, Romance
# 9217  ...  2016  Action, Adventure, Drama, Horror, Science Fiction
# 9218  ...  2016                                 Documentary, Music
#
#                                                keywords  \
# 0     [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1     [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2     [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3     [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4     [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
# ...                                                 ...
# 9214  [{'id': 6054, 'name': 'friendship'}, {'id': 20...
# 9215               [{'id': 10540, 'name': 'bollywood'}]
# 9216               [{'id': 10540, 'name': 'bollywood'}]
# 9217  [{'id': 1299, 'name': 'monster'}, {'id': 7671,...
# 9218  [{'id': 6027, 'name': 'music'}, {'id': 10073, ...
#
#                                                    cast  \
# 0     [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1     [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2     [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3     [{'cast_id': 1, 'character': 'Savannah 'Vannah...
# 4     [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                 ...
# 9214  [{'cast_id': 1, 'character': 'Henry Cobb', 'cr...
# 9215  [{'cast_id': 0, 'character': 'Rustom Pavri', '...
# 9216  [{'cast_id': 0, 'character': 'Sarman', 'credit...
# 9217  [{'cast_id': 4, 'character': 'Rando Yaguchi : ...
# 9218  [{'cast_id': 0, 'character': 'Himself', 'credi...
#
#                                                    crew cast_size  crew_size  \
# 0     [{'credit_id': '52fe4284c3a36847f8024f49', 'de...        13        106
# 1     [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...        26         16
# 2     [{'credit_id': '52fe466a9251416c75077a89', 'de...         7          4
# 3     [{'credit_id': '52fe44779251416c91011acb', 'de...        10         10
# 4     [{'credit_id': '52fe44959251416c75039ed7', 'de...        12          7
# ...                                                 ...       ...        ...
# 9214  [{'credit_id': '544475aac3a36819fb000578', 'de...         7          2
# 9215  [{'credit_id': '5951baf692514129c4016600', 'de...        14         16
# 9216  [{'credit_id': '57cd5d3592514179d50018e8', 'de...        12         16
# 9217  [{'credit_id': '560892fa92514177550018b2', 'de...        49         27
# 9218  [{'credit_id': '57057c6cc3a3680dca000285', 'de...        28          7
#
#                 director                                         cast_names  \
# 0          John Lasseter                  Tom Hanks ,Tim Allen ,Don Rickles
# 1           Joe Johnston       Robin Williams ,Jonathan Hyde ,Kirsten Dunst
# 2          Howard Deutch           Walter Matthau ,Jack Lemmon ,Ann-Margret
# 3        Forest Whitaker    Whitney Houston ,Angela Bassett ,Loretta Devine
# 4          Charles Shyer           Steve Martin ,Diane Keaton ,Martin Short
# ...                  ...                                                ...
# 9214      Gregg Champion      Sidney Poitier ,Wendy Crewson ,Jay O. Sanders
# 9215   Tinu Suresh Desai            Akshay Kumar ,Ileana D'Cruz ,Esha Gupta
# 9216  Ashutosh Gowariker            Hrithik Roshan ,Pooja Hegde ,Kabir Bedi
# 9217        Hideaki Anno  Hiroki Hasegawa ,Yutaka Takenouchi ,Satomi Ish...
# 9218          Ron Howard           Paul McCartney ,Ringo Starr ,John Lennon
#
#                                           keywords_info
# 0     jealousy ,toy ,boy ,friendship ,friends ,rival...
# 1     board game ,disappearance ,based on children's...
# 2     fishing ,best friend ,duringcreditsstinger ,ol...
# 3     based on novel ,interracial relationship ,sing...
# 4     baby ,midlife crisis ,confidence ,aging ,daugh...
# ...                                                 ...
# 9214                           friendship ,brick making
# 9215                                          bollywood
# 9216                                          bollywood
# 9217  monster ,godzilla ,giant monster ,destruction ...
# 9218                                 music ,documentary
#
# [9219 rows x 35 columns]

# %%
# Define a function to compute similarity for each feature using CountVectorizer
def get_similarity_matrix(column):
    count_vectorizer = CountVectorizer(stop_words='english')
    count_matrix = count_vectorizer.fit_transform(small_movies_df[column])
    return cosine_similarity(count_matrix, count_matrix)

# %%
# Calculate similarity matrices for cast, director, keywords, and genre
cast_sim = get_similarity_matrix('cast_names')
director_sim = get_similarity_matrix('director')
keywords_sim = get_similarity_matrix('keywords_info')
genre_sim = get_similarity_matrix('genre')

# %%
# Weights for each feature 
weights = {
    'cast': 0.9,  
    'director': 0.1,  
    'keywords': 0.0,  
    'genre': 0.0  
}

# %%
# Compute the final weighted similarity matrix
final_similarity = (weights['cast'] * cast_sim + 
                    weights['director'] * director_sim + 
                    weights['keywords'] * keywords_sim + 
                    weights['genre'] * genre_sim)

# %%
def get_weighted_recommendations(title, similarity_matrix=final_similarity):
    """Function to get movie recommendations based on weighted similarity"""
    
    idx = small_movies_df[small_movies_df['title'] == title].index[0]   
    sim_scores = list(enumerate(similarity_matrix[idx]))  
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True) 
    sim_scores = sim_scores[1:11]  
    movie_indices = [i[0] for i in sim_scores]
    return small_movies_df[['title', 'cast_names', 'director', 'keywords_info', 'genre']].iloc[movie_indices]

# %%
get_weighted_recommendations('The Dark Knight')
# Out:
#                            title  \
# 6218               Batman Begins
# 6623                The Prestige
# 8031       The Dark Knight Rises
# 5405              Educating Rita
# 1661                     Newsies
# 498                 True Romance
# 1073   The Man Who Would Be King
# 1660  The Muppet Christmas Carol
# 1802             Blame It on Rio
# 1877                   Mona Lisa
#
#                                              cast_names           director  \
# 6218         Christian Bale ,Michael Caine ,Liam Neeson  Christopher Nolan
# 6623        Hugh Jackman ,Christian Bale ,Michael Caine  Christopher Nolan
# 8031         Christian Bale ,Michael Caine ,Gary Oldman  Christopher Nolan
# 5405     Michael Caine ,Julie Walters ,Michael Williams      Lewis Gilbert
# 1661          Christian Bale ,Bill Pullman ,Ann-Margret       Kenny Ortega
# 498   Christian Slater ,Patricia Arquette ,Michael R...         Tony Scott
# 1073   Sean Connery ,Michael Caine ,Christopher Plummer        John Huston
# 1660          Michael Caine ,Don Austen ,Meredith Braun       Brian Henson
# 1802    Michael Caine ,Michelle Johnson ,Joseph Bologna      Stanley Donen
# 1877            Bob Hoskins ,Cathy Tyson ,Michael Caine        Neil Jordan
#
#                                           keywords_info  \
# 6218  himalaya ,martial arts ,dc comics ,crime fight...
# 6623  competition ,secret ,obsession ,magic ,dying a...
# 8031  dc comics ,crime fighter ,terrorist ,secret id...
# 5405
# 1661  juvenile crime ,child empowerment ,brawl ,boy ...
# 498   father son relationship ,film producer ,mexica...
# 1073  robbery ,journalist ,gold ,cheating ,treasure ...
# 1660  holiday ,future ,musical ,past ,scrooge ,chris...
# 1802  female nudity ,infidelity ,rio de janeiro ,sed...
# 1877  london england ,prostitute ,ex-detainee ,chauf...
#
#                                  genre
# 6218              Action, Crime, Drama
# 6623          Drama, Mystery, Thriller
# 8031    Action, Crime, Drama, Thriller
# 5405            Drama, Comedy, Romance
# 1661              Drama, Music, Family
# 498   Action, Thriller, Crime, Romance
# 1073                  Adventure, Drama
# 1660    Comedy, Family, Fantasy, Drama
# 1802                   Comedy, Romance
# 1877             Drama, Crime, Romance
